# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanmoe35/BSIP_Quiz3_Students/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<mxfile host="app.diagrams.net" modified="2025-02-10T12:00:00.000Z" agent="5.0" version="20.6.3">
  <diagram id="ERDiagram" name="Library ERD">
    <mxGraphModel dx="1086" dy="593" grid="1" gridSize="10" guides="1" tooltips="1" connect="1" arrows="1" fold="1" page="1" pageScale="1" pageWidth="850" pageHeight="1100" math="0" shadow="0">
      <root>
        <mxCell id="0"/>
        <mxCell id="1" parent="0"/>

        <!-- Member Entity -->
        <mxCell id="member" value="Member&#xa;--------------------&#xa;MemberID (PK)&#xa;Name&#xa;Email&#xa;Phone" style="shape=rectangle;whiteSpace=wrap;rounded=0;glass=0;strokeColor=#000000;align=center;" vertex="1">
          <mxGeometry x="80" y="140" width="180" height="150" as="geometry"/>
        </mxCell>

        <!-- Book Entity -->
        <mxCell id="book" value="Book&#xa;--------------------&#xa;BookID (PK)&#xa;Title&#xa;Author&#xa;Genre" style="shape=rectangle;whiteSpace=wrap;rounded=0;glass=0;strokeColor=#000000;align=center;" vertex="1">
          <mxGeometry x="480" y="140" width="180" height="150" as="geometry"/>
        </mxCell>

        <!-- Borrowing Entity -->
        <mxCell id="borrowing" value="Borrowing&#xa;--------------------&#xa;BorrowID (PK)&#xa;BorrowDate&#xa;ReturnDate&#xa;MemberID (FK)&#xa;BookID (FK)" style="shape=rectangle;whiteSpace=wrap;rounded=0;glass=0;strokeColor=#000000;align=center;" vertex="1">
          <mxGeometry x="280" y="360" width="200" height="180" as="geometry"/>
        </mxCell>

        <!-- Member to Borrowing Relationship -->
        <mxCell id="edge1" style="edgeStyle=orthogonalEdgeStyle;endArrow=none;html=1;strokeColor=#000000;" edge="1" parent="1">
          <mxGeometry relative="1" as="geometry"/>
          <mxCell source="member" target="borrowing"/>
        </mxCell>

        <!-- Book to Borrowing Relationship -->
        <mxCell id="edge2" style="edgeStyle=orthogonalEdgeStyle;endArrow=none;html=1;strokeColor=#000000;" edge="1" parent="1">
          <mxGeometry relative="1" as="geometry"/>
          <mxCell source="book" target="borrowing"/>
        </mxCell>

      </root>
    </mxGraphModel>
  </diagram>
</mxfile>
